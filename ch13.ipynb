# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('image2.jpg',cv2.IMREAD_COLOR)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
'''
img[10:-5,5:-5,0]=0

img[5:-5,5:-5,2]=0
'''
img[10,10,:]=[255,255,255]

# %%
print(img.shape)
print(img.size)
print(img.dtype)
# Out:
# (449, 800, 3)
# 1077600
# uint8

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
ball = img[280:340, 330:390]
img[273:333, 100:160] = ball

# %%
b,g,r = cv2.split(img)
img = cv2.merge((b,g,r))

# %%
img = cv2.imread('image2.jpg',cv2.IMREAD_COLOR)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img1 = cv2.imread('image2.jpg',cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

#replicate = cv2.copyMakeBorder(img1,200,100,50,100,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,100,10,10,cv2.BORDER_REFLECT)

#plt.imshow(replicate)
plt.imshow(reflect)
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
BLUE = [255,0,0]
img1 = cv2.imread('image2.jpg',cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()

# %%
img1 = cv2.imread('ml.png')
img2 = cv2.imread('opencv_logo.png')
alpha = 0.9
dst = cv2.addWeighted(img1,alpha,img2,1-alpha,0)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1.shape
# Out:
# (500, 500, 3)

# %%
img2.shape
# Out:
# (500, 500, 3)

# %%
img1 = cv2.imread('ml.png')
img2 = cv2.imread('opencv_logo.png')
dst = cv2.addWeighted(img1,0.7,img2,0.3,0)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load two images
img1 = cv2.imread('ml.png')
img2 = cv2.imread('opencv_logo.png')

# %%
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 60, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

plt.imshow(mask,cmap='gray')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
# Load two images
img1 = cv2.imread('image3.jpg')
img2 = cv2.imread('opencv_logo.png')
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
print(rows,cols,channels)
# Out:
# 500 500 3

# %%
roi = img1[0:rows, 0:cols ]
# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
print(img2gray)
plt.imshow(mask,cmap='gray')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
ret, mask = cv2.threshold(img2gray, 100, 200, cv2.THRESH_BINARY)
plt.imshow(mask,cmap='gray')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
mask_inv = cv2.bitwise_not(mask)
plt.imshow(mask_inv,cmap='gray')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)
# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst
plt.imshow(dst,cmap='gray')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()
plt.imshow(img1,cmap='gray')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
cv2.imshow('res',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img1 = cv2.imread('messi5.jpg')
img2 = cv2.imread('opencv_logo.png')
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]
# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 100, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)
# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)
# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst
cv2.imshow('res',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\U209-10\IP2023\ch13.ipynb Cell 23 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-10/IP2023/ch13.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a> # I want to put logo on top-left corner, So I create a ROI
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-10/IP2023/ch13.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a> rows,cols,channels = img2.shape
# ----> <a href='vscode-notebook-cell:/c%3A/Users/U209-10/IP2023/ch13.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a> roi = img1[0:rows, 0:cols ]
#       <a href='vscode-notebook-cell:/c%3A/Users/U209-10/IP2023/ch13.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a> # Now create a mask of logo and create its inverse mask also
#      <a href='vscode-notebook-cell:/c%3A/Users/U209-10/IP2023/ch13.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a> img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
#
# TypeError: 'NoneType' object is not subscriptable
